# %%
#Arredondando para 2 casas
print(round(2.456, 2))
# Out:
# 2.46

# %%
#O comportamento com o.5
print ( round (2.5))
# Out:
# 2

# %%
# O comportamento com o .5
print ( round (2.5) ) # 2 ( arredonda para o par mais
proximo )
print ( round (3.5) ) # 4 ( arredonda para o par mais
proximo )
# Out:
#   Cell In[8], line 3
#     proximo )
#             ^
# SyntaxError: unmatched ')'
